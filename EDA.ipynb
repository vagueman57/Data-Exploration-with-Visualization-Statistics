# %% [markdown]
# # **1.CSV Files**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/nifty_it_index.csv')
df
# Out:
#            Date      Open      High       Low     Close    Volume  \
# 0    2015-01-01  11214.80  11235.75  11166.35  11215.70   4246150
# 1    2015-01-02  11214.65  11399.10  11214.65  11372.10  10004862
# 2    2015-01-05  11369.35  11433.75  11186.95  11248.55   8858018
# 3    2015-01-06  11186.10  11186.10  10909.00  10959.90  12515739
# 4    2015-01-07  11013.20  11042.35  10889.55  10916.00  10976356
# ..          ...       ...       ...       ...       ...       ...
# 243  2015-12-24  11193.25  11197.50  11152.85  11184.90   2927864
# 244  2015-12-28  11152.70  11303.05  11146.85  11271.80   8055590
# 245  2015-12-29  11257.05  11287.50  11206.60  11253.45   6024174
# 246  2015-12-30  11247.35  11263.60  11100.10  11117.60   6564991
# 247  2015-12-31  11113.00  11233.85  11113.00  11212.55   8197040
#
#          Turnover
# 0    3.575100e+09
# 1    9.645600e+09
# 2    1.059000e+10
# 3    1.364500e+10
# 4    1.203440e+10
# ..            ...
# 243  3.182700e+09
# ...

# %% [markdown]
# **### Opening a csv file from url**

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv" # corrected URL
header = {"user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0 "}
req = requests.get(url, headers=header)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %% [markdown]
# Read tsv files

# %%
pd.read_csv('/content/sample-1.tsv', sep='\t', names=['nan', 'month'])
# Out:
#                                                                                                                        nan  \
# NaN NaN     NaN NaN NaN NaN NaN NaN NaN NaN      NaN NaN NaN NaN NaN NaN NaN NaN       NaN NaN NaN NaN NaN NaN NaN  2022.0
#     JANUARY NaN NaN NaN NaN NaN NaN NaN FEBRUARY NaN NaN NaN NaN NaN NaN NaN MARCH     NaN NaN NaN NaN NaN NaN NaN     NaN
#     S       M   T   W   T   F   S   NaN S        M   T   W   T   F   S   NaN S         M   T   W   T   F   S   NaN     NaN
#     NaN     NaN NaN NaN NaN NaN 1   NaN NaN      NaN 1   2   3   4   5   NaN NaN       NaN 1   2   3   4   5   NaN     NaN
#     2       3   4   5   6   7   8   NaN 6        7   8   9   10  11  12  NaN 6         7   8   9   10  11  12  NaN     NaN
#     9       10  11  12  13  14  15  NaN 13       14  15  16  17  18  19  NaN 13        14  15  16  17  18  19  NaN     NaN
# ...

# %%
pd.read_csv('/content/nifty_it_index.csv')
# Out:
#            Date      Open      High       Low     Close    Volume  \
# 0    2015-01-01  11214.80  11235.75  11166.35  11215.70   4246150
# 1    2015-01-02  11214.65  11399.10  11214.65  11372.10  10004862
# 2    2015-01-05  11369.35  11433.75  11186.95  11248.55   8858018
# 3    2015-01-06  11186.10  11186.10  10909.00  10959.90  12515739
# 4    2015-01-07  11013.20  11042.35  10889.55  10916.00  10976356
# ..          ...       ...       ...       ...       ...       ...
# 243  2015-12-24  11193.25  11197.50  11152.85  11184.90   2927864
# 244  2015-12-28  11152.70  11303.05  11146.85  11271.80   8055590
# 245  2015-12-29  11257.05  11287.50  11206.60  11253.45   6024174
# 246  2015-12-30  11247.35  11263.60  11100.10  11117.60   6564991
# 247  2015-12-31  11113.00  11233.85  11113.00  11212.55   8197040
#
#          Turnover
# 0    3.575100e+09
# 1    9.645600e+09
# 2    1.059000e+10
# 3    1.364500e+10
# 4    1.203440e+10
# ..            ...
# 243  3.182700e+09
# ...

# %%
# makinf first row as header
pd.read_csv('/content/nifty_it_index.csv', header=1)
# Out:
#      2015-01-01   11214.8  11235.75  11166.35   11215.7   4246150  \
# 0    2015-01-02  11214.65  11399.10  11214.65  11372.10  10004862
# 1    2015-01-05  11369.35  11433.75  11186.95  11248.55   8858018
# 2    2015-01-06  11186.10  11186.10  10909.00  10959.90  12515739
# 3    2015-01-07  11013.20  11042.35  10889.55  10916.00  10976356
# 4    2015-01-08  11031.15  11058.15  10915.05  11018.15  12975117
# ..          ...       ...       ...       ...       ...       ...
# 242  2015-12-24  11193.25  11197.50  11152.85  11184.90   2927864
# 243  2015-12-28  11152.70  11303.05  11146.85  11271.80   8055590
# 244  2015-12-29  11257.05  11287.50  11206.60  11253.45   6024174
# 245  2015-12-30  11247.35  11263.60  11100.10  11117.60   6564991
# 246  2015-12-31  11113.00  11233.85  11113.00  11212.55   8197040
#
#      3575100000.0
# 0    9.645600e+09
# 1    1.059000e+10
# 2    1.364500e+10
# 3    1.203440e+10
# 4    1.485630e+10
# ..            ...
# 242  3.182700e+09
# ...

# %%
# To get only essential columns
pd.read_csv('/content/nifty_it_index.csv', usecols=['Date', 'Low', 'Close'])
# Out:
#            Date       Low     Close
# 0    2015-01-01  11166.35  11215.70
# 1    2015-01-02  11214.65  11372.10
# 2    2015-01-05  11186.95  11248.55
# 3    2015-01-06  10909.00  10959.90
# 4    2015-01-07  10889.55  10916.00
# ..          ...       ...       ...
# 243  2015-12-24  11152.85  11184.90
# 244  2015-12-28  11146.85  11271.80
# 245  2015-12-29  11206.60  11253.45
# 246  2015-12-30  11100.10  11117.60
# 247  2015-12-31  11113.00  11212.55
#
# [248 rows x 3 columns]

# %%
# skiprows / nrows

pd.read_csv('/content/nifty_it_index.csv', nrows=100)
# Out:
#           Date      Open      High       Low     Close    Volume      Turnover
# 0   2015-01-01  11214.80  11235.75  11166.35  11215.70   4246150  3.575100e+09
# 1   2015-01-02  11214.65  11399.10  11214.65  11372.10  10004862  9.645600e+09
# 2   2015-01-05  11369.35  11433.75  11186.95  11248.55   8858018  1.059000e+10
# 3   2015-01-06  11186.10  11186.10  10909.00  10959.90  12515739  1.364500e+10
# 4   2015-01-07  11013.20  11042.35  10889.55  10916.00  10976356  1.203440e+10
# ..         ...       ...       ...       ...       ...       ...           ...
# 95  2015-05-22  11584.70  11745.75  11562.50  11728.40  15469572  1.465390e+10
# 96  2015-05-25  11740.75  11784.35  11602.10  11623.35  12204690  9.656500e+09
# 97  2015-05-26  11608.75  11649.70  11562.05  11581.90  11485852  9.862600e+09
# 98  2015-05-27  11481.45  11481.45  11338.05  11367.50  34196705  2.348010e+10
# 99  2015-05-28  11368.00  11483.75  11321.65  11450.85  25687562  2.189980e+10
#
# [100 rows x 7 columns]

# %%
pd.read_csv('/content/movies.csv', sep=';', error_bad_lines = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-4cdab9df8cc1> in <cell line: 0>()
# ----> 1 pd.read_csv('/content/movies.csv', sep=';', error_bad_lines = False)
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'

# %%
# reading sep=':'

pd.read_csv('/content/movies.csv', sep=';', on_bad_lines='skip')
# Out:
#                                                                                                                                                                                                 name;"rating";"genre";"year";"released";"score";"votes";"director";"writer";"star";"country";"budget";"gross";"company";"runtime",,
# The Shining;"R";"Drama";1980;"June 13," 1980 (U... 8.4 927000.0  Stanley Kubrick"" Stephen King""            Jack Nicholson"" United Kingdom"" 19000000.0 46998772.0""  Warner Bros.""                                                     146.0",
# The Blue Lagoon;"R";"Adventure";1980;"July 2," ... 5.8 65000.0   Randal Kleiser""  Henry De Vere Stacpoole"" Brooke Shields"" United States""  4500000.0  58853106.0""  Columbia Pictures""                                                104.0",
# ...

# %%
pd.read_csv('/content/movies.csv', sep=';', on_bad_lines='skip')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 4000 entries, ('The Shining;"R";"Drama";1980;"June 13," 1980 (United States)""', 8.4, 927000.0, 'Stanley Kubrick""', 'Stephen King""', 'Jack Nicholson""', 'United Kingdom""', 19000000.0, '46998772.0""', 'Warner Bros.""') to ('Dr. Dolittle 2;"PG";"Comedy";2001;"June 22," 2001 (United States)""', 4.7, 42000.0, 'Steve Carr""', 'Hugh Lofting""', 'Eddie Murphy""', 'United States""', 70000000.0, '176104344.0""', 'Twentieth Century Fox""')
# Data columns (total 1 columns):
#  #   Column                                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                                               --------------  -----
# ...

# %%
# Handling Dates
pd.read_csv('/content/nifty_it_index.csv', parse_dates=['Date'])
# Out:
#           Date      Open      High       Low     Close    Volume      Turnover
# 0   2015-01-01  11214.80  11235.75  11166.35  11215.70   4246150  3.575100e+09
# 1   2015-01-02  11214.65  11399.10  11214.65  11372.10  10004862  9.645600e+09
# 2   2015-01-05  11369.35  11433.75  11186.95  11248.55   8858018  1.059000e+10
# 3   2015-01-06  11186.10  11186.10  10909.00  10959.90  12515739  1.364500e+10
# 4   2015-01-07  11013.20  11042.35  10889.55  10916.00  10976356  1.203440e+10
# ..         ...       ...       ...       ...       ...       ...           ...
# 243 2015-12-24  11193.25  11197.50  11152.85  11184.90   2927864  3.182700e+09
# 244 2015-12-28  11152.70  11303.05  11146.85  11271.80   8055590  1.001900e+10
# 245 2015-12-29  11257.05  11287.50  11206.60  11253.45   6024174  6.626200e+09
# 246 2015-12-30  11247.35  11263.60  11100.10  11117.60   6564991  7.071900e+09
# 247 2015-12-31  11113.00  11233.85  11113.00  11212.55   8197040  8.590500e+09
#
# [248 rows x 7 columns]

# %%
pd.read_csv('/content/nifty_it_index.csv', parse_dates=['Date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      248 non-null    datetime64[ns]
#  1   Open      248 non-null    float64
#  2   High      248 non-null    float64
#  3   Low       248 non-null    float64
#  4   Close     248 non-null    float64
#  5   Volume    248 non-null    int64
#  6   Turnover  248 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.7 KB

# %%
#convertors
pd.read_csv('/content/nifty_it_index.csv', convertors={'Date':rename})

# %%
# Loading a dataset in chunks

dfs=pd.read_csv('/content/nifty_it_index.csv', chunksize=62)

# %%
for chunks in dfs:
    print(chunk.shape)
# Out:
# (62, 7)
# (62, 7)
# (62, 7)
# (62, 7)

# %% [markdown]
# # **2. JSON/SQL**

# %%
pd.read_json('/content/train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ...

# %%
# !pip install mysql.connector

# %%
import mysql.connector

# %%
mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
pd.read_json('https://weatherapi-com.p.rapidapi.com/alerts.json')

# %% [markdown]
# # **3. Web scrapping**

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # **4. Question to ask when encountring data**

# %%
import pandas as pd

# %%
# Analysis on data
df = pd.read_csv('/content/Titanic-Dataset.csv')

# %%
# 1. How Big is Data?
df.shape
# Out:
# (891, 12)

# %%
# 2. How does the data look?
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 878          879         0       3
# 736          737         0       3
# 631          632         0       3
# 835          836         1       1
# 345          346         1       2
# 709          710         1       3
# 192          193         1       3
# 107          108         1       3
# 643          644         1       3
# 295          296         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 736            Ford, Mrs. Edward (Margaret Ann Watson)  female  48.0      1
# 631                        Lundahl, Mr. Johan Svensson    male  51.0      0
# 835                        Compton, Miss. Sara Rebecca  female  39.0      1
# 345                      Brown, Miss. Amelia "Mildred"  female  24.0      0
# 709  Moubarek, Master. Halim Gonios ("William George")    male   NaN      1
# ...

# %%
# 3. What is the Datatypes of cols?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 4. Are there any missing values?
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 5. How does data look mathematically?
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 6. Are there duplicate values?
df.duplicated().sum()
# Out:
# 0

# %%
# How is correlation between cols?
df.corr()['Survived']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-464e62dada27> in <cell line: 0>()
#       1 # How is correlation between cols?
# ----> 2 df.corr()['Survived']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
# ...

# %%
numerical_df = df.select_dtypes(include=['number'])
correlation_matrix = numerical_df.corr()
print(correlation_matrix)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# # **5. EDA using Univariate Analyysis**

# %% [markdown]
# **1. Categorical Data**

# %%
import seaborn as sns

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv')

# %% [markdown]
# (a) Countplot

# %%
# sns.countplot(x='Survived', data=df)
df['Survived'].value_counts().plot(kind='bar')

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %% [markdown]
# ### **(b) PieChart**

# %%
df['Embarked'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## **2. Numerical Data**

# %% [markdown]
# **a. Histogram**

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'], bins=20)
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# **b. Displot**

# %%
sns.distplot(df['Age'])
# Out:
# <ipython-input-68-0fafe04ea3f6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# **c. BoxPlot**

# %%
sns.boxplot(y=df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Fare'].skew()
# Out:
# 4.787316519674893

# %% [markdown]
# # **6. EDA using Bivariate and Multivariate Analysis**

# %%
import pandas as pd
import seaborn as sns

# %%
titanic = pd.read_csv('/content/Titanic-Dataset.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
tips = pd.read_csv('/content/tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flight = pd.read_csv('/content/routes.csv')
flight.head()
# Out:
#   airline airline ID  source airport  source airport id  destination apirport  \
# 0      2B        410             AER               2965                   KZN
# 1      2B        410             ASF               2966                   KZN
# 2      2B        410             ASF               2966                   MRV
# 3      2B        410             CEK               2968                   KZN
# 4      2B        410             CEK               2968                   OVB
#
#    destination airport id  codeshare   stops  equipment
# 0                    2990        NaN       0        CR2
# 1                    2990        NaN       0        CR2
# 2                    2962        NaN       0        CR2
# 3                    2990        NaN       0        CR2
# 4                    4078        NaN       0        CR2

# %%
iris = pd.read_csv('/content/Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ###**1. ScatterPlot(Numerical-Numerical)**

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex', style='smoker', size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ###**2. BarPlot (Numerical-categorical)**

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(x='Pclass', y='Age', data=titanic, hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x='Pclass', y='Fare', data=titanic, hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ###**3. Box Plot(Numerical -Categorical)**

# %%
sns.boxplot(x='Sex', y='Age', data=titanic, hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ###**4. DisPlot (Numerical-Categorical)**

# %%
sns.displot(titanic[titanic['Survived']==0]['Age'])

# %%
sns.displot(data=titanic, x='Age', hue='Survived', kind='kde')

# %% [markdown]
# ###**5. HeatMap(categorical-categorical)**

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'], titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(titanic.groupby('Pclass')['Survived'].mean()*100).plot(kind='pie')
# Out:
# <Axes: ylabel='Survived'>

# %%
titanic.groupby('Embarked')['Survived'].mean()*100
# Out:
# Embarked
# C    55.357143
# Q    38.961039
# S    33.695652
# Name: Survived, dtype: float64

# %%
titanic.groupby('Sex')['Embarked'].value_counts(normalize=True) * 100
# Out:
# Sex     Embarked
# female  S           65.064103
#         C           23.397436
#         Q           11.538462
# male    S           76.429809
#         C           16.464471
#         Q            7.105719
# Name: proportion, dtype: float64

# %%
titanic.groupby('Pclass')['Embarked'].value_counts(normalize=True) * 100
# Out:
# Pclass  Embarked
# 1       S           59.345794
#         C           39.719626
#         Q            0.934579
# 2       S           89.130435
#         C            9.239130
#         Q            1.630435
# 3       S           71.894094
#         Q           14.663951
#         C           13.441955
# Name: proportion, dtype: float64

# %% [markdown]
# ### **6. ClusterMap(categorical-categorical)**

# %%
sns.heatmap(pd.crosstab(titanic['SibSp'], titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='SibSp'>

# %% [markdown]
# ### **7. PairPlot**

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(iris, hue='Species')

# %% [markdown]
# ####**8. LinePlot(Numerical-Numerical)**

# %%
climate = pd.read_csv('/content/DailyDelhiClimateTrain.csv')
climate.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
new = climate.groupby('date').sum().reset_index()

# %%
sns.lineplot(x='date', y='meantemp', data=new)
# Out:
# <Axes: xlabel='date', ylabel='meantemp'>
